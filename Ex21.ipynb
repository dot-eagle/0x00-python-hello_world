# %% [markdown]
# <a href="https://colab.research.google.com/github/dot-eagle/0x00-python-hello_world/blob/master/Ex21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 21 Notebook - Profiling Demo Notebook

# %% [markdown]
# ## 1. Install and import key libraries

# %%
# !pip install ydata_profiling
# !pip install numba --upgrade
# !pip install pyarrow --upgrade
# Out:
# WARNING: Ignoring invalid distribution ~umba (/usr/local/lib/python3.12/dist-packages)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 12.8 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~umba (/usr/local/lib/python3.12/dist-packages)
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.45.1
#     Uninstalling llvmlite-0.45.1:
#       Successfully uninstalled llvmlite-0.45.1
# WARNING: Ignoring invalid distribution ~umba (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umba (/usr/local/lib/python3.12/dist-packages)
# ...
#   Using cached numba-0.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# ...
#   Using cached llvmlite-0.45.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# ...
# Using cached numba-0.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
# ...

# %%
import pandas as pd
import numpy as np

from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ### 2. Create some data frame

# %%
url = 'https://raw.githubusercontent.com/NSCC-ITC-Fall2025-DBAS5115-700-MCr/exercise-21-dot-eagle/refs/heads/main/Titanic_dataset.csv?token=GHSAT0AAAAAADLE5OI6TXMLKQLMKWWMGAKQ2IWRXYQ'
# url = 'https://github.com/NSCC-ITC-Fall2025-DBAS5115-700-MCr/exercise-21-dot-eagle/blob/main/Titanic_dataset.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### 3. Profile Report

# %%
profile = ProfileReport(df, title="Titanic Dataset Profiling Report")
# Out:
# <bound method ProfileReport.to_file of >

# %%
profile.to_file("titanic_profiling_report.html")

# %%
profile.to_notebook_iframe()
#
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-14 01:25:17.371819&quot; name=date&gt;&lt;title&gt;Titanic Dataset Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
